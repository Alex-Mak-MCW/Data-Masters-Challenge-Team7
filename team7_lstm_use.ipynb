# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.random import set_seed

# metrics
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    mean_absolute_percentage_error,
    explained_variance_score
)

# %%
#dat = pd.read_csv("https://media.githubusercontent.com/media/buds-lab/building-data-genome-project-2/refs/heads/master/data/meters/raw/electricity.csv")
dat = pd.read_csv("cleaned_electricity.csv")
dat = dat[dat.columns.difference(["timestamp","month","year","total_energy","z_score","is_anomaly"])]

# %%
# inspecting the dataset
dat
# Out:
#        Bear_assembly_Angel  Bear_assembly_Beatrice  Bear_assembly_Diana  \
# 0                 237.8500                    9.00                1.148
# 1                 221.2500                   10.25                1.148
# 2                 222.5000                   10.00                1.148
# 3                 221.4000                    9.00                1.148
# 4                 224.2500                   10.00                1.148
# ...                    ...                     ...                  ...
# 17517             319.2544                   67.25                0.485
# 17518             313.7506                   66.25                0.429
# 17519             309.0006                   67.75                0.503
# 17520             284.5062                   41.00                0.424
# 17521             286.5000                   32.50                0.655
#
#        Bear_assembly_Genia  Bear_assembly_Jose  Bear_assembly_Roxy  \
# 0                 178.7858              148.50                9.75
# 1                 184.0738              152.00                9.75
# 2                 184.9768              153.25               10.00
# 3                 184.6900              145.50                9.75
# 4                 187.0248              158.25               10.00
# ...                    ...                 ...                 ...
# 17517             403.5352              226.50                7.00
# 17518             396.6962              223.00                6.50
# 17519             305.9935              163.50                6.25
# 17520             195.5648              134.25                6.50
# 17521             192.6955              136.25                7.25
#
#        Bear_assembly_Ruby  Bear_education_Alfredo  Bear_education_Alvaro  \
# 0                   51.50                  0.1025               358.4388
# 1                   52.75                  0.0950               355.8990
# 2                   51.25                  0.1025               328.1848
# 3                   51.00                  0.1025               326.3410
# 4                   51.50                  0.1175               325.4633
# ...                   ...                     ...                    ...
# 17517               68.75                  0.1350               371.8235
# 17518               68.75                  0.1300               371.2127
# 17519               68.00                  0.1300               375.0352
# 17520               68.50                  0.1325               371.4132
# 17521               67.50                  0.1350               359.9163
#
#        Bear_education_Arnold  ...  Wolf_office_Emanuel  Wolf_office_Haydee  \
# 0                      0.519  ...              13.3400              4.9100
# 1                      0.521  ...              13.7975              5.1200
# 2                      0.590  ...              13.3550              4.7325
# 3                      0.539  ...              13.4625              6.6975
# 4                      0.532  ...              13.2375              7.0000
# ...                      ...  ...                  ...                 ...
# 17517                  0.674  ...              10.1650              4.7800
# 17518                  0.694  ...              10.1250              4.7750
# 17519                  0.665  ...              10.1675              4.7925
# 17520                  0.651  ...               9.7475              4.5150
# 17521                  0.702  ...               9.9575              4.8875
#
#        Wolf_office_Joana  Wolf_office_Nadia  Wolf_office_Rochelle  \
# 0                14.6900            50.9975                8.8600
# 1                14.2425            49.9775                8.9625
# 2                14.8850            49.3350                8.8200
# 3                15.3775            50.6450                8.7475
# 4                15.3375            50.9975                8.4475
# ...                  ...                ...                   ...
# 17517            15.3300            57.1650                7.2850
# 17518            15.1600            56.0575                7.3775
# 17519            14.8750            62.7975                7.1525
# 17520            14.4775            54.6325                7.1075
# 17521            14.5525            59.4800                7.5850
#
#        Wolf_public_Norma  Wolf_retail_Harriett  Wolf_retail_Marcella  \
# 0                72.8408               22.7300                9.8575
# 1                67.0392               22.0200                9.6150
# 2                72.3000               22.1100                9.4900
# 3                74.5700               21.5050                9.6125
# 4                71.1233               21.6750                9.4300
# ...                  ...                   ...                   ...
# 17517            56.5333               27.8675                5.4975
# 17518            63.7867               28.2650                5.2050
# 17519            63.0400               28.2425                5.4175
# 17520            62.6133               27.7850                5.0675
# 17521            62.5067               23.2475                5.5250
#
#        Wolf_retail_Toshia  Wolf_science_Alfreda
# 0                 17.6575               87.6400
# 1                 18.5775               87.1525
# 2                 18.1275               86.9800
# 3                 17.4000               87.1375
# 4                 17.3875               86.6425
# ...                   ...                   ...
# 17517             18.1000               72.4275
# 17518             18.5750               73.4875
# 17519             19.0250               72.7675
# 17520             18.2100               72.5375
# 17521             17.7975               72.1025
#
# [17522 rows x 1537 columns]

# %%
n_obs = dat.shape[0]
dat.describe()
# Out:
#        Bear_assembly_Angel  Bear_assembly_Beatrice  Bear_assembly_Diana  \
# count         17522.000000            17522.000000         17522.000000
# mean            476.679703               42.944489             0.894875
# std             167.623822               15.610472             0.345937
# min              36.500000                1.750000             0.000000
# 25%             333.250075               34.250000             0.613000
# 50%             469.545953               37.500000             0.734000
# 75%             608.750000               55.000000             1.148000
# max            1105.600000               83.000000             2.514000
#
#        Bear_assembly_Genia  Bear_assembly_Jose  Bear_assembly_Roxy  \
# count         17522.000000        17522.000000        17522.000000
# mean            263.293742          257.241995           17.080773
# std              83.127254           72.219683           13.478723
# min             151.320800          126.000000            0.000000
# 25%             205.980900          194.250000            9.250000
# 50%             235.312750          249.000000           12.000000
# 75%             287.045000          313.500000           19.000000
# max             613.510000          533.250000           75.398000
#
#        Bear_assembly_Ruby  Bear_education_Alfredo  Bear_education_Alvaro  \
# count        17522.000000            17522.000000           17522.000000
# mean            69.356659                0.181286             419.656757
# std             13.240294                0.090476              61.844445
# min             34.750000                0.050000             219.976000
# 25%             60.500000                0.117500             373.594475
# 50%             68.250000                0.157500             418.574700
# 75%             78.250000                0.217500             465.151750
# max            118.000000                0.630000             600.598800
#
#        Bear_education_Arnold  ...  Wolf_office_Emanuel  Wolf_office_Haydee  \
# count           17522.000000  ...         17522.000000        17522.000000
# mean                0.558994  ...            15.081831            8.626523
# std                 0.363623  ...             6.285490            5.943523
# min                 0.000000  ...             0.000000            0.000000
# 25%                 0.363000  ...            11.180000            4.410000
# 50%                 0.464000  ...            13.267500            6.345000
# 75%                 0.545000  ...            18.936875           10.890000
# max                 2.427000  ...            45.545000           38.472500
#
#        Wolf_office_Joana  Wolf_office_Nadia  Wolf_office_Rochelle  \
# count       17522.000000       17522.000000          17522.000000
# mean           14.815788          74.248859             16.077133
# std             4.982215          22.476497              8.903942
# min             0.000000          28.155000              0.000000
# 25%            11.886250          57.481250              9.005000
# 50%            14.887500          63.441250             12.277500
# 75%            17.346875          93.616875             22.691250
# max            30.580000         162.755000             45.350000
#
#        Wolf_public_Norma  Wolf_retail_Harriett  Wolf_retail_Marcella  \
# count       17522.000000          17522.000000          17522.000000
# mean          146.559584             43.702334              7.002205
# std            73.023355             19.960541              3.235558
# min            17.325000              0.000000              0.002500
# 25%            79.401675             27.737500              4.697500
# 50%           135.229550             39.858750              6.122500
# 75%           205.830850             57.937500              8.625000
# max           330.001700            130.637500             22.645000
#
#        Wolf_retail_Toshia  Wolf_science_Alfreda
# count        17522.000000          17522.000000
# mean            70.893180             81.415206
# std             50.605333             11.897054
# min              7.285000              0.000000
# 25%             30.342500             73.342500
# 50%             39.860000             78.605000
# 75%            119.115625             88.070000
# max            206.440000            124.375000
#
# [8 rows x 1537 columns]

# %%
names = [name.split("_") for name in dat.columns]

# restricting the data to a particular location or use
sub_dfs = dict([])

for use in set([name[1] for name in names]):
  print(use)
  use_inds = np.argwhere(np.array([name[1] == use for name in names])).flatten()
  sub_dfs[use] = dat[dat.columns[use_inds]]
# Out:
# lodging
# education
# office
# assembly
# other
# retail
# parking
# public
# warehouse
# food
# religion
# health
# utility
# science
# industrial
# services

# %%
for building in set([name[0] for name in names]):
  print(building)
  building_inds = np.argwhere(np.array([name[0] == building for name in names])).flatten()
  sub_dfs[building] = dat[dat.columns[building_inds]]
# Out:
# Cockatoo
# Peacock
# Fox
# Lamb
# Bobcat
# Wolf
# Bear
# Mouse
# Panther
# Gator
# Rat
# Crow
# Moose
# Robin
# Shrew
# Eagle
# Hog
# Bull

# %%
sub_dfs["Panther"]
# Out:
#        Panther_assembly_Carrol  Panther_assembly_David  \
# 0                       0.0000                  0.0000
# 1                       0.0000                  0.0000
# 2                       0.0000                  0.0000
# 3                       0.0000                  0.0000
# 4                       0.0000                  0.0000
# ...                        ...                     ...
# 17517                  11.3022                 43.0083
# 17518                  16.4032                 38.6074
# 17519                  12.6024                 38.2074
# 17520                  11.6022                 36.0069
# 17521                   8.6017                 38.2074
#
#        Panther_assembly_Denice  Panther_assembly_Gwyneth  \
# 0                       0.0000                    0.0000
# 1                       0.0000                    0.0000
# 2                       0.0000                    0.0000
# 3                       0.0000                    0.0000
# 4                       0.0000                    0.0000
# ...                        ...                       ...
# 17517                 624.3205                  236.2456
# 17518                 585.8131                  237.8459
# 17519                 570.8102                  203.8393
# 17520                 490.6947                  182.4352
# 17521                 437.0844                  178.6345
#
#        Panther_assembly_Pamella  Panther_education_Alecia  \
# 0                        0.0000                    0.0000
# 1                        0.0000                    0.0000
# 2                        0.0000                    0.0000
# 3                        0.0000                    0.0000
# 4                        0.0000                    0.0000
# ...                         ...                       ...
# 17517                  129.0249                  160.0309
# 17518                  129.2249                  142.0274
# 17519                  129.6250                  148.0286
# 17520                  128.4248                  156.0301
# 17521                  128.2247                  140.0270
#
#        Panther_education_Annetta  Panther_education_Aurora  \
# 0                         0.0000                    0.0000
# 1                         0.0000                    0.0000
# 2                         0.0000                    0.0000
# 3                         0.0000                    0.0000
# 4                         0.0000                    0.0000
# ...                          ...                       ...
# 17517                    79.2153                   68.0131
# 17518                    91.2176                   67.8131
# 17519                    89.2172                   69.0133
# 17520                    87.1168                   67.8131
# 17521                    70.8137                   62.2120
#
#        Panther_education_Cleopatra  Panther_education_Diann  ...  \
# 0                           0.0000                   0.0000  ...
# 1                           0.0000                   0.0000  ...
# 2                           0.0000                   0.0000  ...
# 3                           0.0000                   0.0000  ...
# 4                           0.0000                   0.0000  ...
# ...                            ...                      ...  ...
# 17517                      11.2422                  32.1062  ...
# 17518                      11.2022                  32.7063  ...
# 17519                      11.2822                  34.8067  ...
# 17520                      11.1622                  34.9067  ...
# 17521                      11.2022                  32.5063  ...
#
#        Panther_parking_Jody  Panther_parking_Lorriane  \
# 0                    0.0000                    0.0000
# 1                    0.0000                    0.0000
# 2                    0.0000                    0.0000
# 3                    0.0000                    0.0000
# 4                    0.0000                    0.0000
# ...                     ...                       ...
# 17517               44.2485                   15.4830
# 17518               44.1685                   12.7224
# 17519               44.0085                   11.2822
# 17520               44.0885                   16.9233
# 17521               44.0885                   11.8223
#
#        Panther_parking_Mellissa  Panther_parking_Stanley  \
# 0                        0.0000                   0.0000
# 1                        0.0000                   0.0000
# 2                        0.0000                   0.0000
# 3                        0.0000                   0.0000
# 4                        0.0000                   0.0000
# ...                         ...                      ...
# 17517                   18.8036                  57.7111
# 17518                   18.4035                  57.4111
# 17519                   18.2435                  57.3111
# 17520                   20.4840                  57.6111
# 17521                   17.2833                  57.2110
#
#        Panther_retail_Felix  Panther_retail_Gilbert  Panther_retail_Kristina  \
# 0                    0.0000                  0.0000                   0.0000
# 1                    0.0000                  0.0000                   0.0000
# 2                    0.0000                  0.0000                   0.0000
# 3                    0.0000                  0.0000                   0.0000
# 4                    0.0000                  0.0000                   0.0000
# ...                     ...                     ...                      ...
# 17517               67.0199                  0.6401                  17.9975
# 17518               56.6869                  0.7301                  18.7866
# 17519               55.0576                  0.7201                  18.4526
# 17520               49.6776                  0.7201                  18.2605
# 17521               42.6952                  0.7201                  20.4719
#
#        Panther_retail_Lester  Panther_retail_Rachel  Panther_retail_Romeo
# 0                    15.6030                 0.0000                0.0000
# 1                    15.7230                 0.0000                0.0000
# 2                    16.0831                 0.0000                0.0000
# 3                    15.7230                 0.0000                0.0000
# 4                    15.7230                 0.0000                0.0000
# ...                      ...                    ...                   ...
# 17517                 4.7189                 1.7203              401.8495
# 17518                 4.7149                 1.4403              404.1720
# 17519                 4.7029                 2.0004              406.7715
# 17520                 4.6339                 1.7203              403.3688
# 17521                 4.6729                 1.8404              393.3669
#
# [17522 rows x 105 columns]

# %%
# compute metrics
def compute_metrics(true, pred):
    mae  = mean_absolute_error(true, pred)
    rmse = np.sqrt(mean_squared_error(true, pred))
    mape = mean_absolute_percentage_error(true, pred)
    r2   = r2_score(true, pred)
    ev   = explained_variance_score(true, pred)
    return mae, rmse, mape, r2, ev

fig, ax = plt.subplots(3,6, figsize=(20,10))
locations = list(set([name[1] for name in names]))

models10 = dict([])
models25 = dict([])
test10 = dict([])               # metric to compare models (we'll use MSE to both train and compare)
test25 = dict([])
models = {10: models10, 25: models25}
test = {10: test10, 25: test25}

set_seed(123)                   # set seed for reproducibility, right before using tensorflow functions

for i in range(len(locations)):
  # LSTM is sensitive to scale
  avg_series = sub_dfs[locations[i]].mean(axis=1)   # combine all sequence with a certain use into one sequence to train lstm
  scaler = MinMaxScaler(feature_range=(0, 1))
  scaled_series = scaler.fit_transform(np.array(avg_series).reshape(-1, 1))

  train_size = int(n_obs * 0.8)
  train_scaled = scaled_series[:train_size]
  test_scaled = scaled_series[train_size:]


  # Y is the sequence; for every element of Y, X has a list with the previous look_back entries
  def create_dataset(dataset, look_back=1):
      X, Y = [], []
      for i in range(len(dataset) - look_back - 1):
          a = dataset[i:(i + look_back), 0]
          X.append(a)
          Y.append(dataset[i + look_back, 0])
      return np.array(X), np.array(Y)

  look_back = 4       # informed by arimax giving p = 3, or 4 with small coefficient

  X_train, Y_train = create_dataset(train_scaled, look_back)
  X_test, Y_test = create_dataset(test_scaled, look_back)

  # Reshape input to be [samples, time steps, features] which is required for LSTM
  X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
  X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

  # Building the LSTM model
  for u in [10,25]:
    model = Sequential()
    model.add(LSTM(units=u))
    #model.add(LSTM(units=25))
    model.add(Dense(1))

    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(X_train, Y_train, epochs=3, batch_size=1, verbose=1)
    models[u][locations[i]] = model

    train_predict = model.predict(X_train)
    test_predict = model.predict(X_test)

    # Invert predictions to original scale
    train_predict = scaler.inverse_transform(train_predict)
    real_train = scaler.inverse_transform([Y_train])
    test_predict = scaler.inverse_transform(test_predict)
    real_test = scaler.inverse_transform([Y_test])

    # flatten everything
    y_train_true  = real_train.flatten()
    y_train_pred  = train_predict.flatten()
    y_test_true   = real_test.flatten()
    y_test_pred   = test_predict.flatten()

    #ax[i//6,i%6].plot(y_test_true - y_test_pred)
    #ax[i//6,i%6].set_title(locations[i])

    train_mae, train_rmse, train_mape, train_r2, train_ev = compute_metrics(y_train_true, y_train_pred)
    test_mae,  test_rmse,  test_mape,  test_r2,  test_ev  = compute_metrics(y_test_true,  y_test_pred)
    test[u][locations[i]] = test_rmse

    # print or log them per building
    print(f"===== Metrics for {locations[i]} with units {u} =====")
    print(f" Train →  MAE: {train_mae:.3f}, RMSE: {train_rmse:.3f}, MAPE: {train_mape:.3%}, R²: {train_r2:.3f}, ExplVar: {train_ev:.3f}")
    print(f" Test  →  MAE: {test_mae:.3f},  RMSE: {test_rmse:.3f},  MAPE: {test_mape:.3%},  R²: {test_r2:.3f},  ExplVar: {test_ev:.3f}")
# Out:
# Epoch 1/3
# 14012/14012 ━━━━━━━━━━━━━━━━━━━━ 42s 3ms/step - loss: 0.0028
# Epoch 2/3
# 14012/14012 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 9.7078e-04
# Epoch 3/3
# 14012/14012 ━━━━━━━━━━━━━━━━━━━━ 40s 3ms/step - loss: 9.0449e-04
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ===== Metrics for assembly with units 10 =====
#  Train →  MAE: 2.690, RMSE: 4.734, MAPE: 2.918%, R²: 0.893, ExplVar: 0.907
#  Test  →  MAE: 2.914,  RMSE: 5.368,  MAPE: 3.087%,  R²: 0.860,  ExplVar: 0.870
# Epoch 1/3
# 14012/14012 ━━━━━━━━━━━━━━━━━━━━ 37s 2ms/step - loss: 0.0029
# Epoch 2/3
# 14012/14012 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - loss: 9.2884e-04
# Epoch 3/3
# 14012/14012 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 8.4353e-04
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ===== Metrics for assembly with units 25 =====
#  Train →  MAE: 2.724, RMSE: 4.610, MAPE: 2.939%, R²: 0.898, ExplVar: 0.913
#  Test  →  MAE: 2.958,  RMSE: 5.199,  MAPE: 3.118%,  R²: 0.869,  ExplVar: 0.880
# Epoch 1/3
# 14012/14012 ━━━━━━━━━━━━━━━━━━━━ 36s 2ms/step - loss: 0.0061
# Epoch 2/3
# 14012/14012 ━━━━━━━━━━━━━━━━━━━━ 35s 3ms/step - loss: 0.0014
# Epoch 3/3
# 14012/14012 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - loss: 0.0014
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ===== Metrics for warehouse with units 10 =====
#  Train →  MAE: 1.188, RMSE: 1.809, MAPE: 2.977%, R²: 0.962, ExplVar: 0.963
#  Test  →  MAE: 1.042,  RMSE: 1.518,  MAPE: 3.332%,  R²: 0.905,  ExplVar: 0.909
# Epoch 1/3
# 14012/14012 ━━━━━━━━━━━━━━━━━━━━
#  'industrial': 10.277380086409233,
#  'parking': 2.147970084722476,
#  'utility': 45.53719349660774,
#  'science': 7.266060888842753,
#  'services': 5.237986959411103,
#  'retail': 2.9075635825611768,
#  'office': 3.8535971501596493,
#  'lodging': 3.56749350336259,
#  'education': 6.225339797648903,
#  'food': 7.613414251054592,
#  'religion': 0.7730708724980675,
#  'other': 4.676404880831242,
#  'public': 1.6035424609690272,
#  'health': 7.775250270490809}

# %%
test25
# Out:
# {'assembly': 5.198695510501171,
#  'warehouse': 1.550800388471822,
#  'industrial': 10.227879323005395,
#  'parking': 2.1431413351243997,
#  'utility': 45.241878699018514,
#  'science': 9.61077311214393,
#  'services': 5.2778686419253225,
#  'retail': 2.943578655420473,
#  'office': 3.8610246430570845,
#  'lodging': 3.463429935540384,
#  'education': 6.157913634263803,
#  'food': 7.606577660012746,
#  'religion': 0.7740963219829242,
#  'other': 4.648123514129511,
#  'public': 1.5508449918711718,
#  'health': 7.894870384603613}

# %%
# for each use we trained 2 models, choose whichever had better MSE
better_model = dict([])
for i in locations:
  if test10[i] < test25[i]:
    better_model[i] = models[10][i]
    print(i)
  else:
    better_model[i] = models[25][i]
# Out:
# warehouse
# science
# services
# retail
# office
# religion
# health

# %%
# get a bit of validation data, which are those of individual buildings
import random
random.seed(123)

fig, ax = plt.subplots(5,5, figsize=(10,10))
for i in range(25):
  samp = random.choice(dat.columns)
  location = samp.split("_")[1]

  # get the scaler and model corresponding to the validation sequence
  scaler = MinMaxScaler(feature_range=(0, 1))
  scaler.fit_transform(np.array(sub_dfs[location]).reshape(-1, 1))

  scaled_seq = scaler.fit_transform(np.array(dat[samp]).reshape(-1, 1))
  X_val, Y_val = create_dataset(scaled_seq, look_back)
  X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1], 1))
  val_predict = better_model[location].predict(X_val)

  val_predict = scaler.inverse_transform(val_predict)
  Y_val = scaler.inverse_transform([Y_val])

  # plot series, prediction and diff
  ax[i//5,i%5].plot(Y_val.flatten(), color="r")
  #ax[i//5,i%5].plot(val_predict.flatten(), color="g")
  ax[i//5,i%5].plot(Y_val.flatten() - val_predict.flatten(), color="b")
  ax[i//5,i%5].set_title(samp)

  val_mae, val_rmse, val_mape, val_r2, val_ev = compute_metrics(Y_val.flatten(), val_predict)
  print(f"{samp} → MAE: {val_mae:.3f}, RMSE: {val_rmse:.3f}, R²: {val_r2:.3f}, ExplVar: {val_ev:.3f}")
# Out:
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Bobcat_lodging_Darin → MAE: 9.371, RMSE: 14.668, R²: 0.811, ExplVar: 0.827
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Fox_education_Wendell → MAE: 19.139, RMSE: 30.432, R²: 0.401, ExplVar: 0.602
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Bull_education_Mervin → MAE: 19.085, RMSE: 25.688, R²: 0.613, ExplVar: 0.800
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Lamb_assembly_Corliss → MAE: 3.093, RMSE: 4.320, R²: 0.845, ExplVar: 0.861
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Fox_education_Vernon → MAE: 8.166, RMSE: 11.974, R²: 0.788, ExplVar: 0.829
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Bull_office_Anne → MAE: 1.384, RMSE: 2.205, R²: 0.656, ExplVar: 0.715
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Bear_parking_Gordon → MAE: 0.147, RMSE: 0.274, R²: 0.863, ExplVar: 0.864
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Hog_office_Marilyn → MAE: 2.146, RMSE: 2.879, R²: 0.946, ExplVar: 0.967
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Panther_retail_Lester → MAE: 1.193, RMSE: 1.843, R²: 0.841, ExplVar: 0.841
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Rat_assembly_Frieda → MAE: 9.454, RMSE: 14.011, R²: 0.906, ExplVar: 0.915
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Hog_assembly_Colette → MAE: 50.911, RMSE: 67.415, R²: 0.850, ExplVar: 0.865
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Hog_education_Hallie → MAE: 1.735, RMSE: 2.478, R²: 0.867, ExplVar: 0.895
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Bobcat_education_Whitney → MAE: 40.236, RMSE: 58.307, R²: 0.855, ExplVar: 0.874
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Cockatoo_lodging_Lynne → MAE: 11.091, RMSE: 15.968, R²: 0.773, ExplVar: 0.777
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Cockatoo_education_Jack → MAE: 0.896, RMSE: 1.237, R²: 0.805, ExplVar: 0.813
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Hog_education_Bruno → MAE: 5.491, RMSE: 9.223, R²: 0.933, ExplVar: 0.933
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Rat_assembly_Erwin → MAE: 3.663, RMSE: 5.889, R²: 0.732, ExplVar: 0.739
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Hog_assembly_Jasmine → MAE: 11.182, RMSE: 15.606, R²: 0.623, ExplVar: 0.628
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Rat_warehouse_Eloisa → MAE: 5.842, RMSE: 8.125, R²: 0.988, ExplVar: 0.989
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Fox_education_Elizabeth → MAE: 27.817, RMSE: 41.496, R²: 0.961, ExplVar: 0.961
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Cockatoo_office_Delores → MAE: 4.031, RMSE: 5.617, R²: 0.871, ExplVar: 0.877
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Bear_assembly_Genia → MAE: 30.011, RMSE: 53.956, R²: 0.579, ExplVar: 0.583
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Lamb_education_Hui → MAE: 6.979, RMSE: 7.611, R²: 0.794, ExplVar: 0.921
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Bull_education_Miquel → MAE: 16.814, RMSE: 31.280, R²: 0.814, ExplVar: 0.839
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Rat_education_Fernando → MAE: 4.141, RMSE: 6.095, R²: 0.950, ExplVar: 0.950

# %%
samp = "Cockatoo_office_Delores"

location = samp.split("_")[1]

# get the scaler and model corresponding to the validation sequence
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit_transform(np.array(sub_dfs[location]).reshape(-1, 1))

scaled_seq = scaler.fit_transform(np.array(dat[samp]).reshape(-1, 1))
X_val, Y_val = create_dataset(scaled_seq, look_back)
X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1], 1))
val_predict = better_model[location].predict(X_val)

val_predict = scaler.inverse_transform(val_predict)
Y_val = scaler.inverse_transform([Y_val])

# plot series, prediction and diff
plt.plot(Y_val.flatten(), color="r")
plt.plot(val_predict.flatten(), color="g")
plt.plot(Y_val.flatten() - val_predict.flatten(), color="b")
plt.title(samp)
# Out:
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Text(0.5, 1.0, 'Cockatoo_office_Delores')

# %%
val_mae, val_rmse, val_mape, val_r2, val_ev = compute_metrics(Y_val.flatten(), val_predict)
print(f" Val  →  MAE: {val_mae:.3f},  RMSE: {val_rmse:.3f},  MAPE: {val_mape:.3%},  R²: {val_r2:.3f},  ExplVar: {val_ev:.3f}")
# Out:
#  Val  →  MAE: 4.031,  RMSE: 5.617,  MAPE: 5.404%,  R²: 0.871,  ExplVar: 0.877

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_pacf(dat.mean(axis=1), lags=100, alpha=0.05)
